# %%
import sklearn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv("/home/oscar/Research/HiggsBSM/higgsbsm-fw/hep_data/data/dataframe_electrones_señal_50mil.csv")
df_s = pd.read_csv("/home/oscar/Research/HiggsBSM/higgsbsm-fw/hep_data/data/data_electrons_s_gg2zg.csv")
df_c = pd.read_csv("/home/oscar/Research/HiggsBSM/higgsbsm-fw/hep_data/data/data_electrons_c_gg2zg.csv")
df_b = pd.read_csv("/home/oscar/Research/HiggsBSM/higgsbsm-fw/hep_data/data/data_electrons_b_gg2zg.csv")
#Separar columnas para electrones y positrones
ele_e = df["electron_e"].to_numpy()
ele_px = df["electron_px"].to_numpy()
ele_py = df["electron_py"].to_numpy()
ele_pz = df["electron_pz"].to_numpy()
pos_e = df["positron_e"].to_numpy()
pos_px = df["positron_px"].to_numpy()
pos_py = df["positron_py"].to_numpy()
pos_pz = df["positron_pz"].to_numpy()

ele_e_s = df_s["electron_e_s"].to_numpy()
ele_px_s = df_s["electron_px_s"].to_numpy()
ele_py_s = df_s["electron_py_s"].to_numpy()
ele_pz_s = df_s["electron_pz_s"].to_numpy()
pos_e_s = df_s["positron_e_s"].to_numpy()
pos_px_s = df_s["positron_px_s"].to_numpy()
pos_py_s = df_s["positron_py_s"].to_numpy()
pos_pz_s = df_s["positron_pz_s"].to_numpy()

ele_e_c = df_c["electron_e_c"].to_numpy()
ele_px_c = df_c["electron_px_c"].to_numpy()
ele_py_c = df_c["electron_py_c"].to_numpy()
ele_pz_c = df_c["electron_pz_c"].to_numpy()
pos_e_c = df_c["positron_e_c"].to_numpy()
pos_px_c = df_c["positron_px_c"].to_numpy()
pos_py_c = df_c["positron_py_c"].to_numpy()
pos_pz_c = df_c["positron_pz_c"].to_numpy()

ele_e_b = df_b["electron_e_b"].to_numpy()
ele_px_b = df_b["electron_px_b"].to_numpy()
ele_py_b = df_b["electron_py_b"].to_numpy()
ele_pz_b = df_b["electron_pz_b"].to_numpy()
pos_e_b = df_b["positron_e_b"].to_numpy()
pos_px_b = df_b["positron_px_b"].to_numpy()
pos_py_b = df_b["positron_py_b"].to_numpy()
pos_pz_b = df_b["positron_pz_b"].to_numpy()



#separar columnas para quarks 
quark_e = df["bquark_e_e"].to_numpy()
quark_px = df["bquark_px_e"].to_numpy()
quark_py = df["bquark_py_e"].to_numpy()
quark_pz = df["bquark_pz_e"].to_numpy()
antiquark_e = df["anti_bquark_e_e"].to_numpy()
antiquark_px = df["anti_bquark_px_e"].to_numpy()
antiquark_py = df["anti_bquark_py_e"].to_numpy()
antiquark_pz = df["anti_bquark_pz_e"].to_numpy()

squark_e = df_s["squark_e_e"].to_numpy()
squark_px = df_s["squark_px_e"].to_numpy()
squark_py = df_s["squark_py_e"].to_numpy()
squark_pz = df_s["squark_pz_e"].to_numpy()
anti_squark_e = df_s["anti_squark_e_e"].to_numpy()
anti_squark_px = df_s["anti_squark_px_e"].to_numpy()
anti_squark_py = df_s["anti_squark_py_e"].to_numpy()
anti_squark_pz = df_s["anti_squark_pz_e"].to_numpy()

cquark_e = df_c["cquark_e_e"].to_numpy()
cquark_px = df_c["cquark_px_e"].to_numpy()
cquark_py = df_c["cquark_py_e"].to_numpy()
cquark_pz = df_c["cquark_pz_e"].to_numpy()
anti_cquark_e = df_c["anti_cquark_e_e"].to_numpy()
anti_cquark_px = df_c["anti_cquark_px_e"].to_numpy()
anti_cquark_py = df_c["anti_cquark_py_e"].to_numpy()
anti_cquark_pz = df_c["anti_cquark_pz_e"].to_numpy()

bquark_e = df_b["bquark_e_e"].to_numpy()
bquark_px = df_b["bquark_px_e"].to_numpy()
bquark_py = df_b["bquark_py_e"].to_numpy()
bquark_pz = df_b["bquark_pz_e"].to_numpy()
anti_bquark_e = df_b["anti_bquark_e_e"].to_numpy()
anti_bquark_px = df_b["anti_bquark_px_e"].to_numpy()
anti_bquark_py = df_b["anti_bquark_py_e"].to_numpy()
anti_bquark_pz = df_b["anti_bquark_pz_e"].to_numpy()

Zmass_squared = pow((ele_e + pos_e),2) - pow((ele_px+ pos_px),2) - pow((ele_py + pos_py),2) - pow((ele_pz + pos_pz),2)
Zmass = np.sqrt(Zmass_squared)

Zmass_squared_c = pow((ele_e_c + pos_e_c),2) - pow((ele_px_c+ pos_px_c),2) - pow((ele_py_c + pos_py_c),2) - pow((ele_pz_c + pos_pz_c),2)
Zmass_c = np.sqrt(Zmass_squared_c)

Zmass_squared_b = pow((ele_e_b + pos_e_b),2) - pow((ele_px_b+ pos_px_b),2) - pow((ele_py_b + pos_py_b),2) - pow((ele_pz_b + pos_pz_b),2)
Zmass_b = np.sqrt(Zmass_squared_b)

Zmass_squared_s = pow((ele_e_s + pos_e_s),2) - pow((ele_px_s + pos_px_s),2) - pow((ele_py_s + pos_py_s),2) - pow((ele_pz_s + pos_pz_s),2)
Zmass_s = np.sqrt(Zmass_squared_s)

Zmass_bg = np.concatenate((Zmass_s, Zmass_c, Zmass_b))
#ZpT_squared_b = pow((),2) 
#cos_theta_b = (ele_pz_b + pos_pz_b)/(np.sqrt(pow(ele_px_b + pos_px_b,2) + pow(ele_py_b + pos_py_b,2) + pow(ele_pz_b + pos_pz_b,2)))

#print(Zmass_c)
#plt.hist(Zmass, bins=20, alpha=0.6, color='blue', label='Señal de Z')
plt.hist(Zmass_bg, bins=40,range=(0,180), alpha=1, color='blue', label='Señal de Z (s+c+b)')
plt.hist(Zmass_s, bins=40,range=(0,180), alpha=1, color='red', label='Señal de Z (s)')
plt.hist(Zmass_c, bins=40,range=(0,180), alpha=1, color='green', label='Señal de Z (c)')
plt.hist(Zmass_b, bins=40,range=(0,180), alpha=1, color='orange', label='Señal de Z (b)')
# plt.hist(h_mass_hist, bins=50, range=(0, 250), alpha=0.75, color='green', label='Higgs Mass')
plt.xlabel("Invariant Mass [GeV]")
plt.ylabel("Events")
plt.title("Invariant Mass of Z boson (e)")
#plt.yscale('log')
#plt.title("Invariant Mass of Z Boson")
plt.legend()
plt.show()


gmass_squared_b_e = pow((bquark_e + anti_bquark_e),2) - pow((bquark_px+ anti_bquark_px),2) - pow((bquark_py + anti_bquark_py),2) - pow((bquark_pz + anti_bquark_pz),2)
gmass_b_e = np.sqrt(gmass_squared_b_e)

gmass_squared_c_e = pow((cquark_e + anti_cquark_e),2) - pow((cquark_px+ anti_cquark_px),2) - pow((cquark_py + anti_cquark_py),2) - pow((cquark_pz + anti_cquark_pz),2)
gmass_c_e = np.sqrt(gmass_squared_c_e)

gmass_squared_s_e = pow((squark_e + anti_squark_e),2) - pow((squark_px+ anti_squark_px),2) - pow((squark_py + anti_squark_py),2) - pow((squark_pz + anti_squark_pz),2)
gmass_s_e = np.sqrt(gmass_squared_s_e)

gmass_total_e = np.concatenate((gmass_b_e, gmass_c_e, gmass_s_e))
plt.hist(gmass_total_e, bins=25, range=(0,60),alpha=1, color='orange', label='total reconstruction')
plt.hist(gmass_s_e, bins=25, range=(0,60),alpha=1, color='blue', label='ss reconstruction')
plt.hist(gmass_c_e, bins=25, range=(0,60), alpha=1, color='red', label='cc reconstruction')
plt.hist(gmass_b_e, bins=25, range=(0,60), alpha=1, color='green', label='bb reconstruction')
# plt.hist(h_mass_hist, bins=50, range=(0, 250), alpha=0.75, color='green', label='g Mass')
plt.xlabel("Invariant Mass [GeV]")
plt.ylabel("Events")
plt.title("Invariant Mass of g boson (e)")
#plt.yscale('log')
#plt.title("Invariant Mass of g")
plt.legend()
plt.show()





Zgmass_squared_s = pow((squark_e + anti_squark_e + ele_e_s + pos_e_s),2) - pow((squark_px+ anti_squark_px + ele_px_s + pos_px_s),2) - pow((squark_py + anti_squark_py + ele_py_s + pos_py_s),2) - pow((squark_pz + anti_squark_pz + ele_pz_s + pos_pz_s),2)
Zgmass_s = np.sqrt(Zgmass_squared_s)

Zgmass_squared_c = pow((cquark_e + anti_cquark_e + ele_e_c + pos_e_c),2) - pow((cquark_px+ anti_cquark_px + ele_px_c + pos_px_c),2) - pow((cquark_py + anti_cquark_py + ele_py_c + pos_py_c),2) - pow((cquark_pz + anti_cquark_pz + ele_pz_c + pos_pz_c),2)
Zgmass_c = np.sqrt(Zgmass_squared_c)

Zgmass_squared_b = pow((bquark_e + anti_bquark_e + ele_e_b + pos_e_b),2) - pow((bquark_px+ anti_bquark_px + ele_px_b + pos_px_b),2) - pow((bquark_py + anti_bquark_py + ele_py_b + pos_py_b),2) - pow((bquark_pz + anti_bquark_pz + ele_pz_b + pos_pz_b),2)
Zgmass_b = np.sqrt(Zgmass_squared_b)


plt.hist(Zgmass_s, bins=20, range=(0, 500), alpha=1, color='blue', label='Z --> ee, g --> ssbar')
plt.hist(Zgmass_c, bins=20, range=(0, 500), alpha=1, color='green', label='Z --> ee, g --> ccbar')
plt.hist(Zgmass_b, bins=20, range=(0, 500), alpha=1, color='orange', label='Z --> ee, g --> bbbar')
# plt.hist(h_mass_hist, bins=50, range=(0, 250), alpha=0.75, color='green', label='Higgs Mass')
plt.xlabel("Invariant Mass [GeV]")
plt.ylabel("Events")
plt.title("Invariant Mass of Z + g (e)")
#plt.yscale('log')
#plt.title("Invariant Mass of Higgs Boson")
plt.legend()
plt.show()





'''
Zgmass_squared = pow((quark_e + antiquark_e),2) - pow((quark_px+ antiquark_px),2) - pow((quark_py + antiquark_py),2) - pow((quark_pz + antiquark_pz),2)
Hmass = np.sqrt(Zgmass_squared)

Zgmass_squared_s = pow((squark_e + anti_squark_e + ele_e_s + pos_e_s),2) - pow((squark_px+ anti_squark_px + ele_px_s + pos_px_s),2) - pow((squark_py + anti_squark_py + ele_py_s + pos_py_s),2) - pow((squark_pz + anti_squark_pz + ele_pz_s + pos_pz_s),2)
Zgmass_s = np.sqrt(Zgmass_squared_s)

Zgmass_squared_c = pow((cquark_e + anti_cquark_e + ele_e_c + pos_e_c),2) - pow((cquark_px+ anti_cquark_px + ele_px_c + pos_px_c),2) - pow((cquark_py + anti_cquark_py + ele_py_c + pos_py_c),2) - pow((cquark_pz + anti_cquark_pz + ele_pz_c + pos_pz_c),2)
Zgmass_c = np.sqrt(Zgmass_squared_c)

Zgmass_squared_b = pow((bquark_e + anti_bquark_e + ele_e_b + pos_e_b),2) - pow((bquark_px+ anti_bquark_px + ele_px_b + pos_px_b),2) - pow((bquark_py + anti_bquark_py + ele_py_b + pos_py_b),2) - pow((bquark_pz + anti_bquark_pz + ele_pz_b + pos_pz_b),2)
Zgmass_b = np.sqrt(Zgmass_squared_b)


plt.hist(Hmass, bins=20, range=(0, 500), alpha=1, color='blue', label='Señal de H')
plt.hist(Zgmass_s, bins=20, range=(0, 500), alpha=0.5, color='orange', label='background s')
plt.hist(Hmass_c, bins=20, range=(0, 500), alpha=0.5, color='green', label='background c')
plt.hist(Zgmass_b, bins=20, range=(0, 500), alpha=0.5, color='yellow', label='background b')
# plt.hist(h_mass_hist, bins=50, range=(0, 250), alpha=0.75, color='green', label='Higgs Mass')
plt.xlabel("Invariant Mass [GeV]")
plt.ylabel("Events")
plt.title("Invariant Mass of H boson (e)")
plt.yscale('log')
#plt.title("Invariant Mass of Higgs Boson")
plt.legend()
plt.show()

'''







dfm = pd.read_csv("/home/oscar/Research/HiggsBSM/higgsbsm-fw/hep_data/data/dataframe_muones_señal_50mil.csv")
dfm_s = pd.read_csv("/home/oscar/Research/HiggsBSM/higgsbsm-fw/hep_data/data/data_muons_s_gg2zg.csv")
dfm_c = pd.read_csv("/home/oscar/Research/HiggsBSM/higgsbsm-fw/hep_data/data/data_muons_c_gg2zg.csv")
dfm_b = pd.read_csv("/home/oscar/Research/HiggsBSM/higgsbsm-fw/hep_data/data/data_muons_b_gg2zg.csv")
#Separar columnas para muones y antimuones
muon_e = dfm["muon_e"].to_numpy()
muon_px = dfm["muon_px"].to_numpy()
muon_py = dfm["muon_py"].to_numpy()
muon_pz = dfm["muon_pz"].to_numpy()
antimuon_e = dfm["muon_e"].to_numpy()
antimuon_px = dfm["antimuon_px"].to_numpy()
antimuon_py = dfm["antimuon_py"].to_numpy()
antimuon_pz = dfm["antimuon_pz"].to_numpy()

muon_e_s = dfm_s["muon_e_s"].to_numpy()
muon_px_s = dfm_s["muon_px_s"].to_numpy()
muon_py_s = dfm_s["muon_py_s"].to_numpy()
muon_pz_s = dfm_s["muon_pz_s"].to_numpy()
antimuon_e_s = dfm_s["antimuon_e_s"].to_numpy()
antimuon_px_s = dfm_s["antimuon_px_s"].to_numpy()
antimuon_py_s = dfm_s["antimuon_py_s"].to_numpy()
antimuon_pz_s = dfm_s["antimuon_pz_s"].to_numpy()

muon_e_c = dfm_c["muon_e_c"].to_numpy()
muon_px_c = dfm_c["muon_px_c"].to_numpy()
muon_py_c = dfm_c["muon_py_c"].to_numpy()
muon_pz_c = dfm_c["muon_pz_c"].to_numpy()
antimuon_e_c = dfm_c["antimuon_e_c"].to_numpy()
antimuon_px_c = dfm_c["antimuon_px_c"].to_numpy()
antimuon_py_c = dfm_c["antimuon_py_c"].to_numpy()
antimuon_pz_c = dfm_c["antimuon_pz_c"].to_numpy()

muon_e_b = dfm_b["muon_e_b"].to_numpy()
muon_px_b = dfm_b["muon_px_b"].to_numpy()
muon_py_b = dfm_b["muon_py_b"].to_numpy()
muon_pz_b = dfm_b["muon_pz_b"].to_numpy()
antimuon_e_b = dfm_b["antimuon_e_b"].to_numpy()
antimuon_px_b = dfm_b["antimuon_px_b"].to_numpy()
antimuon_py_b = dfm_b["antimuon_py_b"].to_numpy()
antimuon_pz_b = dfm_b["antimuon_pz_b"].to_numpy()



#separar columnas para quarks 
quark_e_m = dfm["bquark_e_m"].to_numpy()
quark_px_m = dfm["bquark_px_m"].to_numpy()
quark_py_m = dfm["bquark_py_m"].to_numpy()
quark_pz_m = dfm["bquark_pz_m"].to_numpy()
antiquark_e_m = dfm["anti_bquark_e_m"].to_numpy()
antiquark_px_m = dfm["anti_bquark_px_m"].to_numpy()
antiquark_py_m = dfm["anti_bquark_py_m"].to_numpy()
antiquark_pz_m = dfm["anti_bquark_pz_m"].to_numpy()

squark_e_m = dfm_s["squark_e_m"].to_numpy()
squark_px_m = dfm_s["squark_px_m"].to_numpy()
squark_py_m = dfm_s["squark_py_m"].to_numpy()
squark_pz_m = dfm_s["squark_pz_m"].to_numpy()
anti_squark_e_m = dfm_s["anti_squark_e_m"].to_numpy()
anti_squark_px_m = dfm_s["anti_squark_px_m"].to_numpy()
anti_squark_py_m = dfm_s["anti_squark_py_m"].to_numpy()
anti_squark_pz_m = dfm_s["anti_squark_pz_m"].to_numpy()

cquark_e_m = dfm_c["cquark_e_m"].to_numpy()
cquark_px_m = dfm_c["cquark_px_m"].to_numpy()
cquark_py_m = dfm_c["cquark_py_m"].to_numpy()
cquark_pz_m = dfm_c["cquark_pz_m"].to_numpy()
anti_cquark_e_m = dfm_c["anti_cquark_e_m"].to_numpy()
anti_cquark_px_m = dfm_c["anti_cquark_px_m"].to_numpy()
anti_cquark_py_m = dfm_c["anti_cquark_py_m"].to_numpy()
anti_cquark_pz_m = dfm_c["anti_cquark_pz_m"].to_numpy()

bquark_e_m = dfm_b["bquark_e_m"].to_numpy()
bquark_px_m = dfm_b["bquark_px_m"].to_numpy()
bquark_py_m = dfm_b["bquark_py_m"].to_numpy()
bquark_pz_m = dfm_b["bquark_pz_m"].to_numpy()
anti_bquark_e_m = dfm_b["anti_bquark_e_m"].to_numpy()
anti_bquark_px_m = dfm_b["anti_bquark_px_m"].to_numpy()
anti_bquark_py_m = dfm_b["anti_bquark_py_m"].to_numpy()
anti_bquark_pz_m = dfm_b["anti_bquark_pz_m"].to_numpy()



Zmass_squared_m = pow((muon_e + antimuon_e),2) - pow((muon_px+ antimuon_px),2) - pow((muon_py + antimuon_py),2) - pow((muon_pz + antimuon_pz),2)
Zmass_m = np.sqrt(Zmass_squared_m)

Zmass_squared_c_m = pow((muon_e_c + antimuon_e_c),2) - pow((muon_px_c+ antimuon_px_c),2) - pow((muon_py_c + antimuon_py_c),2) - pow((muon_pz_c + antimuon_pz_c),2)
Zmass_c_m = np.sqrt(Zmass_squared_c_m)

Zmass_squared_b_m = pow((muon_e_b + antimuon_e_b),2) - pow((muon_px_b+ antimuon_px_b),2) - pow((muon_py_b + antimuon_py_b),2) - pow((muon_pz_b + antimuon_pz_b),2)
Zmass_b_m = np.sqrt(Zmass_squared_b_m)

Zmass_squared_s_m = pow((muon_e_s + antimuon_e_s),2) - pow((muon_px_s + antimuon_px_s),2) - pow((muon_py_s + antimuon_py_s),2) - pow((muon_pz_s + antimuon_pz_s),2)
Zmass_s_m = np.sqrt(Zmass_squared_s_m)

Zmass_bg_m = np.concatenate((Zmass_s, Zmass_c, Zmass_b))


plt.hist(Zmass_bg_m, bins=40,range=(0,180), alpha=1, color='blue', label='Señal de Z (s+c+b)')
plt.hist(Zmass_s_m, bins=40,range=(0,180), alpha=1, color='red', label='Señal de Z (s)')
plt.hist(Zmass_c_m, bins=40,range=(0,180), alpha=1, color='green', label='Señal de Z (c)')
plt.hist(Zmass_b_m, bins=40,range=(0,180), alpha=1, color='orange', label='Señal de Z (b)')


# plt.hist(h_mass_hist, bins=50, range=(0, 250), alpha=0.75, color='green', label='Higgs Mass')
plt.xlabel("Invariant Mass [GeV]")
plt.ylabel("Events")
plt.title("Invariant Mass of Z boson (muons)")
#plt.yscale('log')
#plt.title("Invariant Mass of Z Boson")
plt.legend()
plt.show()


Z_total_bg = np.concatenate((Zmass_bg, Zmass_bg_m))
plt.hist(Z_total_bg, bins=40,range=(0,180), alpha=1, color='blue', label='Señal de Z (s+c+b)')
# plt.hist(h_mass_hist, bins=50, range=(0, 250), alpha=0.75, color='green', label='Higgs Mass')
plt.xlabel("Invariant Mass [GeV]")
plt.ylabel("Events")
plt.title("Invariant Mass of Z boson (electrons and muons)")
#plt.yscale('log')
#plt.title("Invariant Mass of Z Boson")
plt.legend()
plt.show()






gmass_squared_b_m = pow((bquark_e_m + anti_bquark_e_m),2) - pow((bquark_px_m + anti_bquark_px_m),2) - pow((bquark_py_m + anti_bquark_py_m),2) - pow((bquark_pz_m + anti_bquark_pz_m),2)
gmass_b_m = np.sqrt(gmass_squared_b_m)

gmass_squared_c_m = pow((cquark_e_m + anti_cquark_e_m),2) - pow((cquark_px_m + anti_cquark_px_m),2) - pow((cquark_py_m + anti_cquark_py_m),2) - pow((cquark_pz_m + anti_cquark_pz_m),2)
gmass_c_m = np.sqrt(gmass_squared_c_m)

gmass_squared_s_m = pow((squark_e_m + anti_squark_e_m),2) - pow((squark_px_m + anti_squark_px_m),2) - pow((squark_py_m + anti_squark_py_m),2) - pow((squark_pz_m + anti_squark_pz_m),2)
gmass_s_m = np.sqrt(gmass_squared_s_m)

gmass_total_m = np.concatenate((gmass_b_m, gmass_c_m, gmass_s_m))
#plt.hist(gmass_total_m, bins=25, range=(0,60),alpha=1, color='orange', label='total reconstruction (m)')
plt.hist(gmass_s_m, bins=25, range=(0,60),alpha=1, color='blue', label='ss reconstruction')
plt.hist(gmass_c_m, bins=25, range=(0,60), alpha=1, color='red', label='cc reconstruction')
plt.hist(gmass_b_m, bins=25, range=(0,60), alpha=1, color='green', label='bb reconstruction')
# plt.hist(h_mass_hist, bins=50, range=(0, 250), alpha=0.75, color='green', label='g Mass')
plt.xlabel("Invariant Mass [GeV]")
plt.ylabel("Events")
plt.title("Invariant Mass of g boson (m)")
#plt.yscale('log')
#plt.title("Invariant Mass of g")
plt.legend()
plt.show()


gmass_total_eplusm = np.concatenate((gmass_total_e, gmass_total_m))
plt.hist(gmass_total_eplusm, bins=25, range=(0,60), alpha=1, color='green', label='qqbar reconstruction')
# plt.hist(h_mass_hist, bins=50, range=(0, 250), alpha=0.75, color='green', label='g Mass')
plt.xlabel("Invariant Mass [GeV]")
plt.ylabel("Events")
plt.title("Invariant Mass of g boson (mouns and electrons)")
#plt.yscale('log')
#plt.title("Invariant Mass of g")
plt.legend()
plt.show()





Zgmass_squared_s_m = pow((squark_e_m + anti_squark_e_m + muon_e_s + antimuon_e_s),2) - pow((squark_px_m + anti_squark_px_m + muon_px_s + antimuon_px_s),2) - pow((squark_py_m + anti_squark_py_m + muon_py_s + antimuon_py_s),2) - pow((squark_pz_m + anti_squark_pz_m + muon_pz_s + antimuon_pz_s),2)
Zgmass_s_m = np.sqrt(Zgmass_squared_s_m)

Zgmass_squared_c_m = pow((cquark_e_m + anti_cquark_e_m + muon_e_c + antimuon_e_c),2) - pow((cquark_px_m + anti_cquark_px_m + muon_px_c + antimuon_px_c),2) - pow((cquark_py_m + anti_cquark_py_m + muon_py_c + antimuon_py_c),2) - pow((cquark_pz_m + anti_cquark_pz_m + muon_pz_c + antimuon_pz_c),2)
Zgmass_c_m = np.sqrt(Zgmass_squared_c_m)

Zgmass_squared_b_m = pow((bquark_e_m + anti_bquark_e_m + muon_e_b + antimuon_e_b),2) - pow((bquark_px_m + anti_bquark_px_m + muon_px_b + antimuon_px_b),2) - pow((bquark_py_m + anti_bquark_py_m + muon_py_b + antimuon_py_b),2) - pow((bquark_pz_m + anti_bquark_pz_m + muon_pz_b + antimuon_pz_b),2)
Zgmass_b_m = np.sqrt(Zgmass_squared_b_m)


plt.hist(Zgmass_s_m, bins=20, range=(0, 500), alpha=1, color='blue', label='Z --> mm, g --> ssbar')
plt.hist(Zgmass_c_m, bins=20, range=(0, 500), alpha=1, color='green', label='Z --> mm, g --> ccbar')
plt.hist(Zgmass_b_m, bins=20, range=(0, 500), alpha=1, color='orange', label='Z --> mm, g --> bbbar')
# plt.hist(h_mass_hist, bins=50, range=(0, 250), alpha=0.75, color='green', label='Higgs Mass')
plt.xlabel("Invariant Mass [GeV]")
plt.ylabel("Events")
plt.title("Invariant Mass of Z + g (m)")
#plt.yscale('log')
#plt.title("Invariant Mass of Higgs Boson")
plt.legend()
plt.show()


Zg_total = np.concatenate((Zgmass_b, Zgmass_b_m, Zgmass_c, Zgmass_c_m, Zgmass_s, Zgmass_s_m))
plt.hist(Zg_total, bins=20, range=(0, 500), alpha=1, color='blue', label='Z --> ll, g --> qqbar')
# plt.hist(h_mass_hist, bins=50, range=(0, 250), alpha=0.75, color='green', label='Higgs Mass')
plt.xlabel("Invariant Mass [GeV]")
plt.ylabel("Events")
plt.title("Invariant Mass of Z + g (total)")
#plt.yscale('log')
#plt.title("Invariant Mass of Higgs Boson")
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_247768/1149445452.py:288: RuntimeWarning: invalid value encountered in sqrt
#   Zmass_m = np.sqrt(Zmass_squared_m)

# %%
import torch

# %%
import ml_models

# %%
from ml_models.data_preparation import data_preparation

# %%
data = data_preparation(drop_class=False)

# %%
df_sig = pd.read_csv("/home/oscar/Research/HiggsBSM/higgsbsm-fw/hep_data/data/dataframe_electrones_señal_50mil.csv")
sig_class = np.full(int(len(df_sig.index)), 1)
df_sig.insert(0, "class", sig_class, True)

# %%
#df_bkg = pd.read_csv("/home/oscar/Research/HiggsBSM/higgsbsm-fw/hep_data/data/data_electrons_b_gg2zg.csv")
df_bkg = pd.read_csv("/home/oscar/Research/HiggsBSM/higgsbsm-fw/hep_data/data/dataframe_electrones_señal_50mil.csv")
bkg_class = np.full(int(len(df_bkg.index)), 0)
df_bkg.insert(0, "class", bkg_class, True)

# %%
df_sig.drop("Z_boson_px_e", axis=1)

frames = [df_sig, df_bkg]

# %%
data_set = pd.concat(frames)
data_set.dropna()
# Out:
#        class  electron_px  electron_py  electron_pz  electron_e  positron_px  \
# 0          1   -26.696471    -3.352930     3.095956   27.083734    18.388000
# 1          1     6.168095    80.843066   127.568219  151.153224    17.479197
# 2          1    20.543468    10.971726   -82.887419   86.097254    -7.174135
# 3          1    21.083695   -33.855536    40.208888   56.634567    42.658107
# 4          1    12.942852   -19.216173    13.839460   26.987208    -1.744755
# ...      ...          ...          ...          ...         ...          ...
# 25103      0    23.216277   -49.776451   109.256063  122.284822    12.220089
# 25104      0     1.525081   -59.014577  -171.241247  181.131474     7.926048
# 25105      0   -15.746150   -49.700903   237.054572  242.719985   -95.667817
# 25106      0   -39.915939   -54.735133   -89.738831  112.437871    65.850405
# 25107      0    -9.974909    29.146054    -5.731196   31.334292     4.120310
#
# ...

# %%
data_set.head()
# Out:
#    class  electron_px  electron_py  electron_pz  electron_e  positron_px  \
# 0      1   -26.696471    -3.352930     3.095956   27.083734    18.388000
# 1      1     6.168095    80.843066   127.568219  151.153224    17.479197
# 2      1    20.543468    10.971726   -82.887419   86.097254    -7.174135
# 3      1    21.083695   -33.855536    40.208888   56.634567    42.658107
# 4      1    12.942852   -19.216173    13.839460   26.987208    -1.744755
#
#    positron_py  positron_pz  positron_e  bquark_px_e  bquark_py_e  \
# 0  -106.111834   137.693301  174.806421    -2.088874    26.431097
# 1   -18.649295    96.325398   99.658922    28.031603    26.088300
# 2   -90.154274  -124.687222  154.032999   -45.801304    -4.369251
# 3    43.325967    -1.116444   60.812005   -80.792825    56.649850
# 4   -55.394195  -111.683869  124.678978    25.792098   108.247759
#
#    bquark_pz_e  bquark_e_e  anti_bquark_px_e  anti_bquark_py_e  \
# ...

# %%
Y = data_set["class"]

# %%
X = data_set.drop("class", axis=1)

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC


X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.33, random_state=None)
X_train.dropna()
# Out:
#        electron_px  electron_py  electron_pz  electron_e  positron_px  \
# 9479    -59.342639    11.521495   398.224047  402.786154    22.702843
# 11985     0.444710    -4.637745    60.244889   60.424772    99.823085
# 12678    67.695283    89.197970  -457.536199  471.039597    15.777895
# 24356     1.981404     7.824305    80.992064   81.393244   -14.014478
# 9040     67.939224    22.134972    29.081449   77.145484    -9.756593
# ...            ...          ...          ...         ...          ...
# 23619   -10.522127   -14.113146    18.069074   25.226721    20.205344
# 8024     50.057949   -84.718771   -76.045797  124.362501   -25.557062
# 18887   -57.675767    -1.406896   -45.528067   73.493390   -21.821063
# 5372     40.416764    84.430867   -14.898171   94.784184   -15.793097
# 14512    13.369239   -53.359458   -98.353601  112.691610   -38.843481
#
#        positron_py  positron_pz  positron_e  bquark_px_e  bquark_py_e  \
# ...

# %% [markdown]
# modelo = SVC()

# %%
modelo = SVC()

# %%
modelo.fit(X_train, y_train)
# Out:
# SVC()

# %%
Y_pred = modelo.predict(X_test)

# %%
from sklearn.metrics import precision_score
precision_score(y_test, Y_pred, average=None)
# Out:
# array([0.45158639, 0.46753742])
